# %% [markdown]
# # EMS741 Reptile – Fast GPU Meta-Training with Checkpoints and Visuals
#
# This notebook is designed to run on a GPU server (or Colab GPU). It:
# - downloads and prepares the EMS741 few-shot segmentation dataset,
# - builds a Simple U-Net,
# - runs Reptile meta-training with detailed logging and checkpoints,
# - loads a chosen checkpoint, and
# - evaluates few-shot performance with qualitative images.

# %% [markdown]
# ## 1. Environment and data

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'  # Windows OpenMP fix if needed
print('KMP_DUPLICATE_LIB_OK =', os.environ.get('KMP_DUPLICATE_LIB_OK'))
# Out:
# KMP_DUPLICATE_LIB_OK = TRUE

# %%
# !nvidia-smi -L || echo 'No GPU visible'
# Out:
# GPU 0: NVIDIA A40 (UUID: GPU-258f158f-556e-619c-822d-349eda75d313)

# %%
import os, zipfile, urllib.request, glob, random, json, csv, copy
from datetime import datetime

import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset

import matplotlib.pyplot as plt
from tqdm import tqdm

DATA_URL = 'https://zenodo.org/records/18745413/files/ems741_cw_data.zip?download=1'
ZIP_PATH = 'data.zip'
if not os.path.exists(ZIP_PATH):
    print('Downloading data...')
    urllib.request.urlretrieve(DATA_URL, ZIP_PATH)
    print('Download complete')
with zipfile.ZipFile(ZIP_PATH, 'r') as zf:
    zf.extractall('./')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ## 2. Tasks and in-memory datasets

# %%
TRAIN_ROOT, VAL_ROOT, TEST_ROOT = './train', './val', './test'

def list_tasks(root):
    return sorted([os.path.join(root, d) for d in os.listdir(root) if d.startswith('task_')])

train_tasks = list_tasks(TRAIN_ROOT)
val_tasks   = list_tasks(VAL_ROOT)
test_tasks  = list_tasks(TEST_ROOT)

print('Train tasks:', train_tasks)
print('Val tasks  :', val_tasks)
print('Test tasks :', test_tasks)

class SliceDataset(Dataset):
    def __init__(self, task_root, min_mask_sum=1.0):
        img_dir = os.path.join(task_root, 'images')
        msk_dir = os.path.join(task_root, 'masks')
        img_files = sorted(glob.glob(os.path.join(img_dir, '*.png')))
        msk_files = sorted(glob.glob(os.path.join(msk_dir, '*.png')))
        self.cached = []
        for ip, mp in zip(img_files, msk_files):
            m = np.array(Image.open(mp), dtype=np.float32)
            if m.max() > 1: m = m / 255.0
            if m.sum() >= min_mask_sum:
                img = np.array(Image.open(ip), dtype=np.float32)
                if img.max() > 1: img = img / 255.0
                img = torch.from_numpy(img).float().unsqueeze(0)
                msk = torch.from_numpy(m).float().unsqueeze(0)
                self.cached.append((img, msk))
    def __len__(self):
        return len(self.cached)
    def __getitem__(self, idx):
        return self.cached[idx]

print('Pre-loading slices into RAM...')
cached_datasets = {}
for split, task_list in [('train', train_tasks), ('val', val_tasks), ('test', test_tasks)]:
    for t in tqdm(task_list, desc='Loading {}'.format(split)):
        cached_datasets[t] = SliceDataset(t, min_mask_sum=1.0)
print('Loaded datasets for', len(cached_datasets), 'tasks')
# Out:
# Train tasks: ['./train/task_2', './train/task_3', './train/task_5', './train/task_7']
# Val tasks  : ['./val/task_4', './val/task_6']
# Test tasks : ['./test/task_1', './test/task_8']
# Pre-loading slices into RAM...
# Loading train: 100%|██████████| 4/4 [00:04<00:00,  1.05s/it]
# Loading val: 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Loading test: 100%|██████████| 2/2 [00:01<00:00,  1.72it/s]
# Loaded datasets for 8 tasks

# %% [markdown]
# ## 3. Simple U-Net model

# %%
class SimpleUNet(nn.Module):
    def __init__(self, in_channels=1, out_channels=1):
        super().__init__()
        self.c1a = nn.Conv2d(in_channels, 32, 3, padding=1)
        self.c1b = nn.Conv2d(32, 32, 3, padding=1)
        self.p1 = nn.MaxPool2d(2)
        self.c2a = nn.Conv2d(32, 64, 3, padding=1)
        self.c2b = nn.Conv2d(64, 64, 3, padding=1)
        self.p2 = nn.MaxPool2d(2)
        self.c3a = nn.Conv2d(64, 128, 3, padding=1)
        self.c3b = nn.Conv2d(128, 128, 3, padding=1)
        self.p3 = nn.MaxPool2d(2)
        self.c4a = nn.Conv2d(128, 256, 3, padding=1)
        self.c4b = nn.Conv2d(256, 256, 3, padding=1)
        self.up1 = nn.Upsample(scale_factor=2, mode='nearest')
        self.u1a = nn.Conv2d(256 + 128, 128, 3, padding=1)
        self.u1b = nn.Conv2d(128, 128, 3, padding=1)
        self.up2 = nn.Upsample(scale_factor=2, mode='nearest')
        self.u2a = nn.Conv2d(128 + 64, 64, 3, padding=1)
        self.u2b = nn.Conv2d(64, 64, 3, padding=1)
        self.up3 = nn.Upsample(scale_factor=2, mode='nearest')
        self.u3a = nn.Conv2d(64 + 32, 32, 3, padding=1)
        self.u3b = nn.Conv2d(32, 32, 3, padding=1)
        self.out = nn.Conv2d(32, out_channels, 1)
        self.act = nn.ReLU(inplace=True)
        self.final = nn.Sigmoid()
    def forward(self, x):
        x1 = self.act(self.c1b(self.act(self.c1a(x)))); p1 = self.p1(x1)
        x2 = self.act(self.c2b(self.act(self.c2a(p1)))); p2 = self.p2(x2)
        x3 = self.act(self.c3b(self.act(self.c3a(p2)))); p3 = self.p3(x3)
        b  = self.act(self.c4b(self.act(self.c4a(p3))))
        y = self.up1(b); y = torch.cat([y, x3], dim=1); y = self.act(self.u1b(self.act(self.u1a(y))))
        y = self.up2(y); y = torch.cat([y, x2], dim=1); y = self.act(self.u2b(self.act(self.u2a(y))))
        y = self.up3(y); y = torch.cat([y, x1], dim=1); y = self.act(self.u3b(self.act(self.u3a(y))))
        return self.final(self.out(y))

print('Model params:', sum(p.numel() for p in SimpleUNet().parameters()) )
# Out:
# Model params: 1946305

# %% [markdown]
# ## 4. Losses and metrics

# %%
def soft_dice_loss(pred, target, eps=1e-6):
    inter = (pred * target).sum(dim=(1,2,3))
    union = pred.sum(dim=(1,2,3)) + target.sum(dim=(1,2,3))
    dice = (2 * inter + eps) / (union + eps)
    return 1.0 - dice.mean()

def dice_score(pred, target, eps=1e-6):
    p = (pred > 0.5).float(); t = target.float()
    inter = (p * t).sum(dim=(1,2,3)); union = p.sum(dim=(1,2,3)) + t.sum(dim=(1,2,3))
    return ((2 * inter + eps) / (union + eps)).mean().item()

# %% [markdown]
# ## 5. Task sampling

# %%
def sample_task_episode(task_root, k_support=4, k_query=4):
    ds = cached_datasets[task_root]
    n = len(ds)
    if n == 0:
        raise ValueError('No usable slices in {}'.format(task_root))
    idxs = np.random.permutation(n)
    k_total = min(n, k_support + k_query)
    k_s = min(k_support, k_total // 2)
    k_q = min(k_query, k_total - k_s)
    xs, ys = zip(*[ds[i] for i in idxs[:k_s]])
    xq, yq = zip(*[ds[i] for i in idxs[k_s:k_s+k_q]]) if k_q > 0 else ([], [])
    xs = torch.stack(xs); ys = torch.stack(ys)
    xq = torch.stack(xq) if len(xq) else None
    yq = torch.stack(yq) if len(yq) else None
    return xs, ys, xq, yq

# %% [markdown]
# ## 6. Inner-loop adaptation (per task)

# %%
def inner_update(model, x_s, y_s, steps=3, lr_inner=1e-3, device=device):
    fast = copy.deepcopy(model).to(device)
    opt = torch.optim.SGD(fast.parameters(), lr=lr_inner)
    x_s, y_s = x_s.to(device), y_s.to(device)
    for _ in range(steps):
        opt.zero_grad()
        out = fast(x_s)
        if out.shape != y_s.shape: y_s = y_s.view_as(out)
        loss = F.binary_cross_entropy(out, y_s) + soft_dice_loss(out, y_s)
        loss.backward()
        opt.step()
    return fast

# %% [markdown]
# ## 7. Reptile meta-training with checkpoints

# %%
meta_config = {
    'meta_iters': 200,
    'tasks_per_batch': 2,
    'k_support': 4,
    'k_query': 4,
    'lr_inner': 1e-3,
    'lr_meta': 0.1,
}

checkpoint_dir = 'checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)

def reptile_meta_train(model, train_tasks, device=device):
    model.to(device); model.train()
    meta_loss_history = []
    total_iters = meta_config['meta_iters']
    for it in range(total_iters):
        iter_start = datetime.now()
        meta_losses = []
        # zero pseudo-gradients
        for p in model.parameters():
            p.grad = torch.zeros_like(p.data)
        used_tasks = random.sample(train_tasks, k=min(meta_config['tasks_per_batch'], len(train_tasks)))
        print('=== Meta iteration {}/{} ==='.format(it+1, total_iters))
        print('Using tasks:', [os.path.basename(t) for t in used_tasks])
        for task_root in used_tasks:
            xs, ys, xq, yq = sample_task_episode(task_root, meta_config['k_support'], meta_config['k_query'])
            print('  Task {}: support {}, query {}'.format(os.path.basename(task_root), xs.shape, None if xq is None else xq.shape))
            fast_model = inner_update(model, xs, ys, steps=3, lr_inner=meta_config['lr_inner'], device=device)
            if xq is not None and yq is not None:
                xq, yq = xq.to(device), yq.to(device)
                with torch.no_grad():
                    out_q = fast_model(xq)
                    if out_q.shape != yq.shape: yq = yq.view_as(out_q)
                    bce = F.binary_cross_entropy(out_q, yq)
                    dls = soft_dice_loss(out_q, yq)
                    loss_q = bce + dls
                    meta_losses.append(loss_q.item())
                    print('    query BCE {:.4f}, DiceLoss {:.4f}, total {:.4f}'.format(bce.item(), dls.item(), loss_q.item()))
            for p, pf in zip(model.parameters(), fast_model.parameters()):
                p.grad.data.add_(pf.data - p.data)
        for p in model.parameters():
            p.grad.data.div_(len(used_tasks))
            p.data.add_(meta_config['lr_meta'] * p.grad.data)
        mean_loss = float('nan') if len(meta_losses) == 0 else float(np.mean(meta_losses))
        meta_loss_history.append(mean_loss)
        dt = (datetime.now() - iter_start).total_seconds()
        print('[Meta {}] mean query loss {:.4f}, took {:.1f}s'.format(it+1, mean_loss, dt))
        if (it + 1) % 25 == 0:
            ckpt = {'model_state': model.state_dict(), 'meta_loss_history': meta_loss_history, 'iter': it+1}
            path = os.path.join(checkpoint_dir, 'meta_iter_{}.pt'.format(it+1))
            torch.save(ckpt, path)
            print('  Saved checkpoint at iteration', it+1, '->', path)
    return meta_loss_history

meta_model = SimpleUNet(in_channels=1, out_channels=1)
meta_loss_history = reptile_meta_train(meta_model, train_tasks, device=device)
# Out:
# === Meta iteration 1/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7579, DiceLoss 0.9462, total 1.7041
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7574, DiceLoss 0.9380, total 1.6955
# [Meta 1] mean query loss 1.6998, took 2.3s
# === Meta iteration 2/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7600, DiceLoss 0.9768, total 1.7368
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7559, DiceLoss 0.9213, total 1.6771
# [Meta 2] mean query loss 1.7069, took 0.6s
# === Meta iteration 3/200 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7563, DiceLoss 0.9284, total 1.6846
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7583, DiceLoss 0.9560, total 1.7143
# [Meta 3] mean query loss 1.6994, took 0.5s
# === Meta iteration 4/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7578, DiceLoss 0.9491, total 1.7069
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7591, DiceLoss 0.9688, total 1.7279
# [Meta 4] mean query loss 1.7174, took 0.5s
# === Meta iteration 5/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7593, DiceLoss 0.9746, total 1.7339
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7580, DiceLoss 0.9559, total 1.7140
# [Meta 5] mean query loss 1.7239, took 0.5s
# === Meta iteration 6/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7589, DiceLoss 0.9688, total 1.7277
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7573, DiceLoss 0.9439, total 1.7012
# [Meta 6] mean query loss 1.7145, took 0.5s
# === Meta iteration 7/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7580, DiceLoss 0.9579, total 1.7159
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7554, DiceLoss 0.9229, total 1.6783
# [Meta 7] mean query loss 1.6971, took 0.6s
# === Meta iteration 8/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7580, DiceLoss 0.9563, total 1.7143
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7562, DiceLoss 0.9337, total 1.6898
# [Meta 8] mean query loss 1.7021, took 0.5s
# === Meta iteration 9/200 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7547, DiceLoss 0.9163, total 1.6709
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7580, DiceLoss 0.9589, total 1.7169
# [Meta 9] mean query loss 1.6939, took 0.5s
# === Meta iteration 10/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7562, DiceLoss 0.9383, total 1.6946
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7563, DiceLoss 0.9385, total 1.6948
# [Meta 10] mean query loss 1.6947, took 0.5s
# === Meta iteration 11/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7569, DiceLoss 0.9467, total 1.7036
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7574, DiceLoss 0.9559, total 1.7133
# [Meta 11] mean query loss 1.7085, took 0.5s
# === Meta iteration 12/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7588, DiceLoss 0.9754, total 1.7342
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7569, DiceLoss 0.9491, total 1.7059
# [Meta 12] mean query loss 1.7201, took 0.5s
# === Meta iteration 13/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7581, DiceLoss 0.9701, total 1.7282
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7596, DiceLoss 0.9887, total 1.7482
# [Meta 13] mean query loss 1.7382, took 0.5s
# === Meta iteration 14/200 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7546, DiceLoss 0.9203, total 1.6749
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7564, DiceLoss 0.9473, total 1.7038
# [Meta 14] mean query loss 1.6894, took 0.5s
# === Meta iteration 15/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7585, DiceLoss 0.9748, total 1.7333
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7560, DiceLoss 0.9401, total 1.6961
# [Meta 15] mean query loss 1.7147, took 0.5s
# === Meta iteration 16/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7561, DiceLoss 0.9421, total 1.6982
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7553, DiceLoss 0.9355, total 1.6909
# [Meta 16] mean query loss 1.6945, took 0.5s
# === Meta iteration 17/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7562, DiceLoss 0.9437, total 1.6999
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7557, DiceLoss 0.9403, total 1.6960
# [Meta 17] mean query loss 1.6979, took 0.5s
# === Meta iteration 18/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7547, DiceLoss 0.9285, total 1.6832
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7537, DiceLoss 0.9154, total 1.6691
# [Meta 18] mean query loss 1.6762, took 0.5s
# === Meta iteration 19/200 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7538, DiceLoss 0.9170, total 1.6708
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7561, DiceLoss 0.9472, total 1.7033
# [Meta 19] mean query loss 1.6870, took 0.5s
# === Meta iteration 20/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7567, DiceLoss 0.9572, total 1.7139
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7555, DiceLoss 0.9402, total 1.6957
# [Meta 20] mean query loss 1.7048, took 0.5s
# === Meta iteration 21/200 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7574, DiceLoss 0.9697, total 1.7271
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7555, DiceLoss 0.9418, total 1.6973
# [Meta 21] mean query loss 1.7122, took 0.5s
# === Meta iteration 22/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7557, DiceLoss 0.9448, total 1.7005
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7506, DiceLoss 0.8827, total 1.6333
# [Meta 22] mean query loss 1.6669, took 0.5s
# === Meta iteration 23/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7563, DiceLoss 0.9567, total 1.7130
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7542, DiceLoss 0.9251, total 1.6793
# [Meta 23] mean query loss 1.6961, took 0.6s
# === Meta iteration 24/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7572, DiceLoss 0.9716, total 1.7287
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7557, DiceLoss 0.9516, total 1.7074
# [Meta 24] mean query loss 1.7180, took 0.5s
# === Meta iteration 25/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7561, DiceLoss 0.9575, total 1.7136
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7565, DiceLoss 0.9628, total 1.7193
# [Meta 25] mean query loss 1.7165, took 0.5s
#   Saved checkpoint at iteration 25 -> checkpoints/meta_iter_25.pt
# === Meta iteration 26/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7551, DiceLoss 0.9422, total 1.6973
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7557, DiceLoss 0.9520, total 1.7077
# [Meta 26] mean query loss 1.7025, took 0.5s
# === Meta iteration 27/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7556, DiceLoss 0.9540, total 1.7096
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7560, DiceLoss 0.9608, total 1.7168
# [Meta 27] mean query loss 1.7132, took 0.5s
# === Meta iteration 28/200 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7547, DiceLoss 0.9409, total 1.6957
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7577, DiceLoss 0.9846, total 1.7423
# [Meta 28] mean query loss 1.7190, took 0.6s
# === Meta iteration 29/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7538, DiceLoss 0.9313, total 1.6851
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7494, DiceLoss 0.8738, total 1.6232
# [Meta 29] mean query loss 1.6542, took 0.5s
# === Meta iteration 30/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7549, DiceLoss 0.9476, total 1.7025
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7541, DiceLoss 0.9370, total 1.6912
# [Meta 30] mean query loss 1.6968, took 0.5s
# === Meta iteration 31/200 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7547, DiceLoss 0.9453, total 1.7000
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7560, DiceLoss 0.9633, total 1.7193
# [Meta 31] mean query loss 1.7096, took 0.5s
# === Meta iteration 32/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7544, DiceLoss 0.9429, total 1.6973
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7523, DiceLoss 0.9155, total 1.6678
# [Meta 32] mean query loss 1.6825, took 0.5s
# === Meta iteration 33/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7537, DiceLoss 0.9349, total 1.6886
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7523, DiceLoss 0.9156, total 1.6679
# [Meta 33] mean query loss 1.6783, took 0.5s
# === Meta iteration 34/200 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7522, DiceLoss 0.9143, total 1.6665
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7539, DiceLoss 0.9381, total 1.6919
# [Meta 34] mean query loss 1.6792, took 0.5s
# === Meta iteration 35/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7545, DiceLoss 0.9500, total 1.7044
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7537, DiceLoss 0.9359, total 1.6896
# [Meta 35] mean query loss 1.6970, took 0.5s
# === Meta iteration 36/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7539, DiceLoss 0.9425, total 1.6964
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7539, DiceLoss 0.9406, total 1.6945
# [Meta 36] mean query loss 1.6955, took 0.5s
# === Meta iteration 37/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7539, DiceLoss 0.9438, total 1.6977
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7527, DiceLoss 0.9258, total 1.6785
# [Meta 37] mean query loss 1.6881, took 0.5s
# === Meta iteration 38/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7545, DiceLoss 0.9529, total 1.7074
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7538, DiceLoss 0.9416, total 1.6953
# [Meta 38] mean query loss 1.7014, took 0.5s
# === Meta iteration 39/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7554, DiceLoss 0.9669, total 1.7223
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7550, DiceLoss 0.9645, total 1.7195
# [Meta 39] mean query loss 1.7209, took 0.5s
# === Meta iteration 40/200 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7498, DiceLoss 0.8951, total 1.6449
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7544, DiceLoss 0.9552, total 1.7097
# [Meta 40] mean query loss 1.6773, took 0.5s
# === Meta iteration 41/200 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7545, DiceLoss 0.9562, total 1.7107
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7521, DiceLoss 0.9246, total 1.6767
# [Meta 41] mean query loss 1.6937, took 0.5s
# === Meta iteration 42/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7544, DiceLoss 0.9570, total 1.7114
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7540, DiceLoss 0.9499, total 1.7039
# [Meta 42] mean query loss 1.7076, took 0.5s
# === Meta iteration 43/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7527, DiceLoss 0.9330, total 1.6856
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7529, DiceLoss 0.9372, total 1.6901
# [Meta 43] mean query loss 1.6879, took 0.5s
# === Meta iteration 44/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7524, DiceLoss 0.9319, total 1.6844
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7532, DiceLoss 0.9423, total 1.6955
# [Meta 44] mean query loss 1.6899, took 0.5s
# === Meta iteration 45/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7531, DiceLoss 0.9426, total 1.6957
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7534, DiceLoss 0.9482, total 1.7016
# [Meta 45] mean query loss 1.6987, took 0.5s
# === Meta iteration 46/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7532, DiceLoss 0.9457, total 1.6989
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7543, DiceLoss 0.9619, total 1.7162
# [Meta 46] mean query loss 1.7076, took 0.5s
# === Meta iteration 47/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7517, DiceLoss 0.9261, total 1.6778
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7534, DiceLoss 0.9500, total 1.7034
# [Meta 47] mean query loss 1.6906, took 0.5s
# === Meta iteration 48/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7510, DiceLoss 0.9175, total 1.6685
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7538, DiceLoss 0.9569, total 1.7108
# [Meta 48] mean query loss 1.6897, took 0.5s
# === Meta iteration 49/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7531, DiceLoss 0.9485, total 1.7016
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7536, DiceLoss 0.9560, total 1.7096
# [Meta 49] mean query loss 1.7056, took 0.5s
# === Meta iteration 50/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7520, DiceLoss 0.9333, total 1.6853
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7533, DiceLoss 0.9527, total 1.7059
# [Meta 50] mean query loss 1.6956, took 0.5s
#   Saved checkpoint at iteration 50 -> checkpoints/meta_iter_50.pt
# === Meta iteration 51/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7518, DiceLoss 0.9322, total 1.6839
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7535, DiceLoss 0.9589, total 1.7124
# [Meta 51] mean query loss 1.6982, took 0.5s
# === Meta iteration 52/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7510, DiceLoss 0.9229, total 1.6738
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7538, DiceLoss 0.9652, total 1.7191
# [Meta 52] mean query loss 1.6964, took 0.5s
# === Meta iteration 53/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7533, DiceLoss 0.9596, total 1.7129
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7532, DiceLoss 0.9570, total 1.7102
# [Meta 53] mean query loss 1.7116, took 0.5s
# === Meta iteration 54/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7536, DiceLoss 0.9642, total 1.7178
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7527, DiceLoss 0.9508, total 1.7036
# [Meta 54] mean query loss 1.7107, took 0.5s
# === Meta iteration 55/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7536, DiceLoss 0.9652, total 1.7187
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7493, DiceLoss 0.9042, total 1.6535
# [Meta 55] mean query loss 1.6861, took 0.5s
# === Meta iteration 56/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7521, DiceLoss 0.9431, total 1.6952
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7523, DiceLoss 0.9471, total 1.6994
# [Meta 56] mean query loss 1.6973, took 0.5s
# === Meta iteration 57/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7515, DiceLoss 0.9368, total 1.6883
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7512, DiceLoss 0.9332, total 1.6844
# [Meta 57] mean query loss 1.6863, took 0.5s
# === Meta iteration 58/200 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7502, DiceLoss 0.9209, total 1.6711
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7522, DiceLoss 0.9477, total 1.6999
# [Meta 58] mean query loss 1.6855, took 0.5s
# === Meta iteration 59/200 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7517, DiceLoss 0.9429, total 1.6946
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7530, DiceLoss 0.9629, total 1.7158
# [Meta 59] mean query loss 1.7052, took 0.5s
# === Meta iteration 60/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7516, DiceLoss 0.9428, total 1.6945
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7505, DiceLoss 0.9324, total 1.6829
# [Meta 60] mean query loss 1.6887, took 0.5s
# === Meta iteration 61/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7528, DiceLoss 0.9642, total 1.7170
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7511, DiceLoss 0.9390, total 1.6900
# [Meta 61] mean query loss 1.7035, took 0.5s
# === Meta iteration 62/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7513, DiceLoss 0.9409, total 1.6923
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7493, DiceLoss 0.9133, total 1.6626
# [Meta 62] mean query loss 1.6774, took 0.5s
# === Meta iteration 63/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7512, DiceLoss 0.9424, total 1.6936
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7518, DiceLoss 0.9513, total 1.7031
# [Meta 63] mean query loss 1.6983, took 0.5s
# === Meta iteration 64/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7536, DiceLoss 0.9811, total 1.7346
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7513, DiceLoss 0.9451, total 1.6964
# [Meta 64] mean query loss 1.7155, took 0.6s
# === Meta iteration 65/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7528, DiceLoss 0.9686, total 1.7214
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7512, DiceLoss 0.9446, total 1.6958
# [Meta 65] mean query loss 1.7086, took 0.5s
# === Meta iteration 66/200 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7515, DiceLoss 0.9512, total 1.7027
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7518, DiceLoss 0.9556, total 1.7075
# [Meta 66] mean query loss 1.7051, took 0.5s
# === Meta iteration 67/200 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7504, DiceLoss 0.9371, total 1.6876
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7488, DiceLoss 0.9129, total 1.6618
# [Meta 67] mean query loss 1.6747, took 0.5s
# === Meta iteration 68/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7511, DiceLoss 0.9478, total 1.6989
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7514, DiceLoss 0.9527, total 1.7041
# [Meta 68] mean query loss 1.7015, took 0.6s
# === Meta iteration 69/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7514, DiceLoss 0.9556, total 1.7071
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7510, DiceLoss 0.9469, total 1.6979
# [Meta 69] mean query loss 1.7025, took 0.5s
# === Meta iteration 70/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7493, DiceLoss 0.9252, total 1.6745
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7500, DiceLoss 0.9354, total 1.6854
# [Meta 70] mean query loss 1.6800, took 0.5s
# === Meta iteration 71/200 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7465, DiceLoss 0.8882, total 1.6347
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7516, DiceLoss 0.9608, total 1.7125
# [Meta 71] mean query loss 1.6736, took 0.5s
# === Meta iteration 72/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7517, DiceLoss 0.9640, total 1.7158
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7512, DiceLoss 0.9558, total 1.7070
# [Meta 72] mean query loss 1.7114, took 0.5s
# === Meta iteration 73/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7508, DiceLoss 0.9517, total 1.7025
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7500, DiceLoss 0.9390, total 1.6889
# [Meta 73] mean query loss 1.6957, took 0.5s
# === Meta iteration 74/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7511, DiceLoss 0.9578, total 1.7089
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7492, DiceLoss 0.9289, total 1.6780
# [Meta 74] mean query loss 1.6935, took 0.5s
# === Meta iteration 75/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7518, DiceLoss 0.9695, total 1.7212
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7494, DiceLoss 0.9343, total 1.6837
# [Meta 75] mean query loss 1.7025, took 0.5s
#   Saved checkpoint at iteration 75 -> checkpoints/meta_iter_75.pt
# === Meta iteration 76/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7502, DiceLoss 0.9465, total 1.6967
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7464, DiceLoss 0.8924, total 1.6388
# [Meta 76] mean query loss 1.6678, took 0.5s
# === Meta iteration 77/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7496, DiceLoss 0.9383, total 1.6879
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7500, DiceLoss 0.9447, total 1.6947
# [Meta 77] mean query loss 1.6913, took 0.5s
# === Meta iteration 78/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7494, DiceLoss 0.9382, total 1.6876
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7509, DiceLoss 0.9621, total 1.7131
# [Meta 78] mean query loss 1.7003, took 0.5s
# === Meta iteration 79/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7504, DiceLoss 0.9552, total 1.7056
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7500, DiceLoss 0.9508, total 1.7009
# [Meta 79] mean query loss 1.7032, took 0.5s
# === Meta iteration 80/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7496, DiceLoss 0.9437, total 1.6933
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7502, DiceLoss 0.9528, total 1.7030
# [Meta 80] mean query loss 1.6982, took 0.5s
# === Meta iteration 81/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7500, DiceLoss 0.9521, total 1.7021
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7491, DiceLoss 0.9380, total 1.6871
# [Meta 81] mean query loss 1.6946, took 0.5s
# === Meta iteration 82/200 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7486, DiceLoss 0.9318, total 1.6804
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7509, DiceLoss 0.9676, total 1.7186
# [Meta 82] mean query loss 1.6995, took 0.5s
# === Meta iteration 83/200 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7461, DiceLoss 0.8986, total 1.6446
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7496, DiceLoss 0.9490, total 1.6986
# [Meta 83] mean query loss 1.6716, took 0.5s
# === Meta iteration 84/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7480, DiceLoss 0.9257, total 1.6737
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7486, DiceLoss 0.9360, total 1.6846
# [Meta 84] mean query loss 1.6792, took 0.5s
# === Meta iteration 85/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7492, DiceLoss 0.9459, total 1.6951
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7494, DiceLoss 0.9481, total 1.6975
# [Meta 85] mean query loss 1.6963, took 0.5s
# === Meta iteration 86/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7502, DiceLoss 0.9625, total 1.7127
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7502, DiceLoss 0.9634, total 1.7136
# [Meta 86] mean query loss 1.7131, took 0.5s
# === Meta iteration 87/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7498, DiceLoss 0.9591, total 1.7089
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7479, DiceLoss 0.9302, total 1.6782
# [Meta 87] mean query loss 1.6935, took 0.5s
# === Meta iteration 88/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7511, DiceLoss 0.9823, total 1.7335
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7494, DiceLoss 0.9531, total 1.7025
# [Meta 88] mean query loss 1.7180, took 0.5s
# === Meta iteration 89/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7493, DiceLoss 0.9535, total 1.7027
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7508, DiceLoss 0.9779, total 1.7287
# [Meta 89] mean query loss 1.7157, took 0.5s
# === Meta iteration 90/200 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7478, DiceLoss 0.9332, total 1.6811
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7486, DiceLoss 0.9448, total 1.6935
# [Meta 90] mean query loss 1.6873, took 0.5s
# === Meta iteration 91/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7483, DiceLoss 0.9412, total 1.6895
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7482, DiceLoss 0.9395, total 1.6877
# [Meta 91] mean query loss 1.6886, took 0.6s
# === Meta iteration 92/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7482, DiceLoss 0.9420, total 1.6902
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7500, DiceLoss 0.9694, total 1.7194
# [Meta 92] mean query loss 1.7048, took 0.5s
# === Meta iteration 93/200 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7487, DiceLoss 0.9497, total 1.6983
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7481, DiceLoss 0.9418, total 1.6898
# [Meta 93] mean query loss 1.6941, took 0.5s
# === Meta iteration 94/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7491, DiceLoss 0.9589, total 1.7080
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7491, DiceLoss 0.9584, total 1.7075
# [Meta 94] mean query loss 1.7078, took 0.5s
# === Meta iteration 95/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7492, DiceLoss 0.9629, total 1.7121
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7460, DiceLoss 0.9122, total 1.6582
# [Meta 95] mean query loss 1.6852, took 0.5s
# === Meta iteration 96/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7476, DiceLoss 0.9379, total 1.6854
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7464, DiceLoss 0.9206, total 1.6670
# [Meta 96] mean query loss 1.6762, took 0.5s
# === Meta iteration 97/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7471, DiceLoss 0.9325, total 1.6796
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7457, DiceLoss 0.9132, total 1.6589
# [Meta 97] mean query loss 1.6693, took 0.5s
# === Meta iteration 98/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7489, DiceLoss 0.9619, total 1.7108
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7493, DiceLoss 0.9699, total 1.7192
# [Meta 98] mean query loss 1.7150, took 0.5s
# === Meta iteration 99/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7476, DiceLoss 0.9431, total 1.6907
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7480, DiceLoss 0.9490, total 1.6970
# [Meta 99] mean query loss 1.6938, took 0.5s
# === Meta iteration 100/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7470, DiceLoss 0.9365, total 1.6835
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7499, DiceLoss 0.9826, total 1.7325
# [Meta 100] mean query loss 1.7080, took 0.5s
#   Saved checkpoint at iteration 100 -> checkpoints/meta_iter_100.pt
# === Meta iteration 101/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7475, DiceLoss 0.9448, total 1.6923
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7466, DiceLoss 0.9299, total 1.6766
# [Meta 101] mean query loss 1.6844, took 0.5s
# === Meta iteration 102/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7480, DiceLoss 0.9549, total 1.7029
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7474, DiceLoss 0.9451, total 1.6925
# [Meta 102] mean query loss 1.6977, took 0.5s
# === Meta iteration 103/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7471, DiceLoss 0.9414, total 1.6885
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7455, DiceLoss 0.9170, total 1.6625
# [Meta 103] mean query loss 1.6755, took 0.5s
# === Meta iteration 104/200 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7451, DiceLoss 0.9163, total 1.6614
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7472, DiceLoss 0.9461, total 1.6934
# [Meta 104] mean query loss 1.6774, took 0.5s
# === Meta iteration 105/200 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7471, DiceLoss 0.9433, total 1.6904
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7478, DiceLoss 0.9560, total 1.7037
# [Meta 105] mean query loss 1.6970, took 0.5s
# === Meta iteration 106/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7479, DiceLoss 0.9594, total 1.7073
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7458, DiceLoss 0.9259, total 1.6716
# [Meta 106] mean query loss 1.6894, took 0.5s
# === Meta iteration 107/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7471, DiceLoss 0.9478, total 1.6949
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7464, DiceLoss 0.9375, total 1.6839
# [Meta 107] mean query loss 1.6894, took 0.5s
# === Meta iteration 108/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7479, DiceLoss 0.9630, total 1.7110
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7442, DiceLoss 0.9040, total 1.6482
# [Meta 108] mean query loss 1.6796, took 0.5s
# === Meta iteration 109/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7476, DiceLoss 0.9593, total 1.7069
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7444, DiceLoss 0.9083, total 1.6526
# [Meta 109] mean query loss 1.6798, took 0.5s
# === Meta iteration 110/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7458, DiceLoss 0.9329, total 1.6787
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7454, DiceLoss 0.9265, total 1.6720
# [Meta 110] mean query loss 1.6753, took 0.5s
# === Meta iteration 111/200 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7451, DiceLoss 0.9222, total 1.6673
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7468, DiceLoss 0.9518, total 1.6986
# [Meta 111] mean query loss 1.6829, took 0.5s
# === Meta iteration 112/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7460, DiceLoss 0.9394, total 1.6854
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7455, DiceLoss 0.9315, total 1.6770
# [Meta 112] mean query loss 1.6812, took 0.5s
# === Meta iteration 113/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7469, DiceLoss 0.9547, total 1.7015
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7430, DiceLoss 0.8959, total 1.6389
# [Meta 113] mean query loss 1.6702, took 0.6s
# === Meta iteration 114/200 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7452, DiceLoss 0.9338, total 1.6790
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7446, DiceLoss 0.9206, total 1.6652
# [Meta 114] mean query loss 1.6721, took 0.5s
# === Meta iteration 115/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7461, DiceLoss 0.9448, total 1.6908
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7456, DiceLoss 0.9359, total 1.6815
# [Meta 115] mean query loss 1.6862, took 0.5s
# === Meta iteration 116/200 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7426, DiceLoss 0.8921, total 1.6347
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7453, DiceLoss 0.9336, total 1.6788
# [Meta 116] mean query loss 1.6568, took 0.5s
# === Meta iteration 117/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7467, DiceLoss 0.9585, total 1.7053
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7465, DiceLoss 0.9551, total 1.7016
# [Meta 117] mean query loss 1.7034, took 0.5s
# === Meta iteration 118/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7464, DiceLoss 0.9558, total 1.7022
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7442, DiceLoss 0.9210, total 1.6652
# [Meta 118] mean query loss 1.6837, took 0.5s
# === Meta iteration 119/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7435, DiceLoss 0.9112, total 1.6548
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7427, DiceLoss 0.9003, total 1.6430
# [Meta 119] mean query loss 1.6489, took 0.6s
# === Meta iteration 120/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7460, DiceLoss 0.9516, total 1.6976
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7457, DiceLoss 0.9465, total 1.6922
# [Meta 120] mean query loss 1.6949, took 0.5s
# === Meta iteration 121/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7459, DiceLoss 0.9516, total 1.6975
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7456, DiceLoss 0.9481, total 1.6938
# [Meta 121] mean query loss 1.6956, took 0.5s
# === Meta iteration 122/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7461, DiceLoss 0.9577, total 1.7038
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7426, DiceLoss 0.9022, total 1.6449
# [Meta 122] mean query loss 1.6743, took 0.5s
# === Meta iteration 123/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7451, DiceLoss 0.9443, total 1.6894
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7440, DiceLoss 0.9251, total 1.6691
# ...
#     query BCE 0.7419, DiceLoss 0.9538, total 1.6957
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7412, DiceLoss 0.9403, total 1.6816
# [Meta 160] mean query loss 1.6886, took 0.5s
# === Meta iteration 161/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7403, DiceLoss 0.9252, total 1.6655
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7400, DiceLoss 0.9200, total 1.6600
# [Meta 161] mean query loss 1.6627, took 0.5s
# === Meta iteration 162/200 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7429, DiceLoss 0.9726, total 1.7155
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7423, DiceLoss 0.9634, total 1.7057
# [Meta 162] mean query loss 1.7106, took 0.5s
# === Meta iteration 163/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7410, DiceLoss 0.9417, total 1.6827
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7406, DiceLoss 0.9360, total 1.6766
# [Meta 163] mean query loss 1.6797, took 0.5s
# === Meta iteration 164/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7421, DiceLoss 0.9632, total 1.7053
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7422, DiceLoss 0.9661, total 1.7083
# [Meta 164] mean query loss 1.7068, took 0.6s
# === Meta iteration 165/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7411, DiceLoss 0.9485, total 1.6896
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7422, DiceLoss 0.9658, total 1.7080
# [Meta 165] mean query loss 1.6988, took 0.5s
# === Meta iteration 166/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7413, DiceLoss 0.9532, total 1.6945
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7410, DiceLoss 0.9488, total 1.6898
# [Meta 166] mean query loss 1.6921, took 0.5s
# === Meta iteration 167/200 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7398, DiceLoss 0.9278, total 1.6676
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7419, DiceLoss 0.9648, total 1.7066
# [Meta 167] mean query loss 1.6871, took 0.5s
# === Meta iteration 168/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7406, DiceLoss 0.9442, total 1.6848
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7403, DiceLoss 0.9388, total 1.6791
# [Meta 168] mean query loss 1.6819, took 0.5s
# === Meta iteration 169/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7418, DiceLoss 0.9675, total 1.7093
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7398, DiceLoss 0.9318, total 1.6717
# [Meta 169] mean query loss 1.6905, took 0.6s
# === Meta iteration 170/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7382, DiceLoss 0.9038, total 1.6421
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7406, DiceLoss 0.9478, total 1.6884
# [Meta 170] mean query loss 1.6652, took 0.5s
# === Meta iteration 171/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7405, DiceLoss 0.9482, total 1.6887
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7417, DiceLoss 0.9696, total 1.7112
# [Meta 171] mean query loss 1.6999, took 0.5s
# === Meta iteration 172/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7403, DiceLoss 0.9432, total 1.6835
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7407, DiceLoss 0.9519, total 1.6926
# [Meta 172] mean query loss 1.6881, took 0.5s
# === Meta iteration 173/200 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7408, DiceLoss 0.9557, total 1.6965
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7420, DiceLoss 0.9774, total 1.7194
# [Meta 173] mean query loss 1.7080, took 0.5s
# === Meta iteration 174/200 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7393, DiceLoss 0.9298, total 1.6691
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7416, DiceLoss 0.9732, total 1.7148
# [Meta 174] mean query loss 1.6919, took 0.5s
# === Meta iteration 175/200 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7402, DiceLoss 0.9490, total 1.6891
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7401, DiceLoss 0.9471, total 1.6872
# [Meta 175] mean query loss 1.6882, took 0.5s
#   Saved checkpoint at iteration 175 -> checkpoints/meta_iter_175.pt
# === Meta iteration 176/200 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7397, DiceLoss 0.9429, total 1.6826
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7406, DiceLoss 0.9590, total 1.6996
# [Meta 176] mean query loss 1.6911, took 0.5s
# === Meta iteration 177/200 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7393, DiceLoss 0.9358, total 1.6751
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7365, DiceLoss 0.8890, total 1.6255
# [Meta 177] mean query loss 1.6503, took 0.5s
# === Meta iteration 178/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7404, DiceLoss 0.9596, total 1.7001
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7406, DiceLoss 0.9620, total 1.7026
# [Meta 178] mean query loss 1.7013, took 0.6s
# === Meta iteration 179/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7394, DiceLoss 0.9421, total 1.6815
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7393, DiceLoss 0.9415, total 1.6808
# [Meta 179] mean query loss 1.6812, took 0.5s
# === Meta iteration 180/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7408, DiceLoss 0.9697, total 1.7105
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7373, DiceLoss 0.9081, total 1.6455
# [Meta 180] mean query loss 1.6780, took 0.5s
# === Meta iteration 181/200 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7374, DiceLoss 0.9098, total 1.6473
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7403, DiceLoss 0.9646, total 1.7049
# [Meta 181] mean query loss 1.6761, took 0.5s
# === Meta iteration 182/200 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7409, DiceLoss 0.9756, total 1.7165
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7394, DiceLoss 0.9471, total 1.6864
# [Meta 182] mean query loss 1.7015, took 0.5s
# === Meta iteration 183/200 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7398, DiceLoss 0.9546, total 1.6944
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7409, DiceLoss 0.9785, total 1.7193
# [Meta 183] mean query loss 1.7069, took 0.5s
# === Meta iteration 184/200 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7378, DiceLoss 0.9225, total 1.6603
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7398, DiceLoss 0.9573, total 1.6971
# [Meta 184] mean query loss 1.6787, took 0.5s
# === Meta iteration 185/200 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7393, DiceLoss 0.9515, total 1.6908
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7389, DiceLoss 0.9420, total 1.6809
# [Meta 185] mean query loss 1.6858, took 0.5s
# === Meta iteration 186/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7391, DiceLoss 0.9549, total 1.6940
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7388, DiceLoss 0.9452, total 1.6841
# [Meta 186] mean query loss 1.6890, took 0.5s
# === Meta iteration 187/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7365, DiceLoss 0.9029, total 1.6394
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7403, DiceLoss 0.9758, total 1.7161
# [Meta 187] mean query loss 1.6777, took 0.5s
# === Meta iteration 188/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7384, DiceLoss 0.9402, total 1.6786
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7390, DiceLoss 0.9502, total 1.6892
# [Meta 188] mean query loss 1.6839, took 0.5s
# === Meta iteration 189/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7379, DiceLoss 0.9361, total 1.6740
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7392, DiceLoss 0.9579, total 1.6971
# [Meta 189] mean query loss 1.6855, took 0.5s
# === Meta iteration 190/200 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7389, DiceLoss 0.9539, total 1.6928
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7396, DiceLoss 0.9668, total 1.7064
# [Meta 190] mean query loss 1.6996, took 0.5s
# === Meta iteration 191/200 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7382, DiceLoss 0.9449, total 1.6831
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7378, DiceLoss 0.9341, total 1.6719
# [Meta 191] mean query loss 1.6775, took 0.5s
# === Meta iteration 192/200 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7387, DiceLoss 0.9514, total 1.6901
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7372, DiceLoss 0.9210, total 1.6581
# [Meta 192] mean query loss 1.6741, took 0.6s
# === Meta iteration 193/200 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7381, DiceLoss 0.9415, total 1.6796
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7389, DiceLoss 0.9573, total 1.6962
# [Meta 193] mean query loss 1.6879, took 0.5s
# === Meta iteration 194/200 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7380, DiceLoss 0.9451, total 1.6831
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7384, DiceLoss 0.9529, total 1.6914
# [Meta 194] mean query loss 1.6872, took 0.5s
# === Meta iteration 195/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7389, DiceLoss 0.9644, total 1.7033
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7381, DiceLoss 0.9463, total 1.6843
# [Meta 195] mean query loss 1.6938, took 0.5s
# === Meta iteration 196/200 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7379, DiceLoss 0.9444, total 1.6822
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7365, DiceLoss 0.9204, total 1.6569
# [Meta 196] mean query loss 1.6695, took 0.5s
# === Meta iteration 197/200 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7359, DiceLoss 0.9097, total 1.6455
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7378, DiceLoss 0.9455, total 1.6832
# [Meta 197] mean query loss 1.6644, took 0.5s
# === Meta iteration 198/200 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7384, DiceLoss 0.9571, total 1.6955
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7372, DiceLoss 0.9377, total 1.6749
# [Meta 198] mean query loss 1.6852, took 0.5s
# === Meta iteration 199/200 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7370, DiceLoss 0.9329, total 1.6698
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7370, DiceLoss 0.9333, total 1.6703
# [Meta 199] mean query loss 1.6701, took 0.5s
# === Meta iteration 200/200 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7382, DiceLoss 0.9604, total 1.6986
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7371, DiceLoss 0.9385, total 1.6756
# [Meta 200] mean query loss 1.6871, took 0.5s
#   Saved checkpoint at iteration 200 -> checkpoints/meta_iter_200.pt

# %% [markdown]
# ## 8. Load a chosen checkpoint (optional)

# %%
# Set this to the checkpoint you want to resume/evaluate from
checkpoint_path = os.path.join('checkpoints', 'meta_iter_150.pt')  # change if needed

if os.path.exists(checkpoint_path):
    ckpt = torch.load(checkpoint_path, map_location=device)
    meta_model = SimpleUNet(in_channels=1, out_channels=1).to(device)
    meta_model.load_state_dict(ckpt['model_state'])
    print('Loaded checkpoint from:', checkpoint_path)
    print('Stored iteration index:', ckpt.get('iter'))
    print('Last 10 meta-loss values:', ckpt.get('meta_loss_history', [])[-10:])
else:
    print('Checkpoint not found at', checkpoint_path, '- using freshly trained meta_model instead.')
# Out:
# Loaded checkpoint from: checkpoints/meta_iter_150.pt
# Stored iteration index: 150
# Last 10 meta-loss values: [1.6789627075195312, 1.677405297756195, 1.67598557472229, 1.6811506152153015, 1.676193118095398, 1.6828073859214783, 1.6767684817314148, 1.666506052017212, 1.6684614419937134, 1.6649404168128967]

# %% [markdown]
# ## 9. Few-shot evaluation with qualitative images

# %%
def eval_task_with_images(model, task_root, shots=4, steps=10, lr_inner=1e-3, device=device, n_vis=3, batch_size=8):
    ds = cached_datasets[task_root]
    n = len(ds)
    if n <= shots:
        raise ValueError('Not enough slices in {}'.format(task_root))
    idxs = np.random.permutation(n)
    xs, ys = zip(*[ds[i] for i in idxs[:shots]])
    xs, ys = torch.stack(xs).to(device), torch.stack(ys).to(device)
    
    # **Batch query** 
    query_idxs = idxs[shots:]
    dice_scores = []
    adapted = copy.deepcopy(model).to(device)
    opt = torch.optim.SGD(adapted.parameters(), lr=lr_inner)
    for _ in range(steps):
        opt.zero_grad()
        out_s = adapted(xs)
        if out_s.shape != ys.shape: ys = ys.view_as(out_s)
        loss = F.binary_cross_entropy(out_s, ys) + soft_dice_loss(out_s, ys)
        loss.backward()
        opt.step()
    
    with torch.no_grad():
        for i in range(0, len(query_idxs), batch_size):
            end = min(i + batch_size, len(query_idxs))
            xq_b, yq_b = zip(*[ds[j] for j in query_idxs[i:end]])
            xq_b, yq_b = torch.stack(xq_b).to(device), torch.stack(yq_b).to(device)
            out_q_b = adapted(xq_b)
            d_b = dice_score(out_q_b.cpu(), yq_b.cpu())
            dice_scores.append(d_b)
    
    mean_dice = float(np.mean(dice_scores))
    print('Task {} | {}-shot Dice: {:.4f}'.format(os.path.basename(task_root), shots, mean_dice))
    
    # Visuals from first batch only
    k = min(n_vis, xq_b.shape[0])
    for i in range(k):
        img = xq_b[i,0].cpu().numpy()
        gt  = yq_b[i,0].cpu().numpy()
        pr  = (out_q_b[i,0].cpu().numpy() > 0.5).astype(float)
        fig, axs = plt.subplots(1,3,figsize=(9,3))
        axs[0].imshow(img, cmap='gray'); axs[0].set_title('Image'); axs[0].axis('off')
        axs[1].imshow(gt, cmap='gray'); axs[1].set_title('GT mask'); axs[1].axis('off')
        axs[2].imshow(pr, cmap='gray'); axs[2].set_title('Pred mask'); axs[2].axis('off')
        plt.show()
    return mean_dice

print('Running qualitative evaluation on first few val tasks...')
for t in val_tasks[:2]:
    for s in [1, 3, 5]:
        eval_task_with_images(meta_model, t, shots=s, steps=10, lr_inner=1e-3, device=device, n_vis=2)
# Out:
# Running qualitative evaluation on first few val tasks...
# Task task_4 | 1-shot Dice: 0.0380
# Task task_4 | 3-shot Dice: 0.0382
# Task task_4 | 5-shot Dice: 0.0381
# Task task_6 | 1-shot Dice: 0.0703
# Task task_6 | 3-shot Dice: 0.0703
# Task task_6 | 5-shot Dice: 0.0700
