# %% [markdown]
# # EMS741 Reptile – Fast GPU Meta-Training with Checkpoints and Visuals
#
# This notebook is designed to run on a GPU server (or Colab GPU). It:
# - downloads and prepares the EMS741 few-shot segmentation dataset,
# - builds a Simple U-Net,
# - runs Reptile meta-training with detailed logging and checkpoints,
# - loads a chosen checkpoint, and
# - evaluates few-shot performance with qualitative images.

# %% [markdown]
# ## 1. Environment and data

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'  # Windows OpenMP fix if needed
print('KMP_DUPLICATE_LIB_OK =', os.environ.get('KMP_DUPLICATE_LIB_OK'))
# Out:
# KMP_DUPLICATE_LIB_OK = TRUE

# %%
# !nvidia-smi -L || echo 'No GPU visible'
# Out:
# GPU 0: NVIDIA A40 (UUID: GPU-258f158f-556e-619c-822d-349eda75d313)

# %%
import os, zipfile, urllib.request, glob, random, json, csv, copy
from datetime import datetime

import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset

import matplotlib.pyplot as plt
from tqdm import tqdm

DATA_URL = 'https://zenodo.org/records/18745413/files/ems741_cw_data.zip?download=1'
ZIP_PATH = 'data.zip'
if not os.path.exists(ZIP_PATH):
    print('Downloading data...')
    urllib.request.urlretrieve(DATA_URL, ZIP_PATH)
    print('Download complete')
with zipfile.ZipFile(ZIP_PATH, 'r') as zf:
    zf.extractall('./')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ## 2. Tasks and in-memory datasets

# %%
TRAIN_ROOT, VAL_ROOT, TEST_ROOT = './train', './val', './test'

def list_tasks(root):
    return sorted([os.path.join(root, d) for d in os.listdir(root) if d.startswith('task_')])

train_tasks = list_tasks(TRAIN_ROOT)
val_tasks   = list_tasks(VAL_ROOT)
test_tasks  = list_tasks(TEST_ROOT)

print('Train tasks:', train_tasks)
print('Val tasks  :', val_tasks)
print('Test tasks :', test_tasks)

class SliceDataset(Dataset):
    def __init__(self, task_root, min_mask_sum=1.0):
        img_dir = os.path.join(task_root, 'images')
        msk_dir = os.path.join(task_root, 'masks')
        img_files = sorted(glob.glob(os.path.join(img_dir, '*.png')))
        msk_files = sorted(glob.glob(os.path.join(msk_dir, '*.png')))
        self.cached = []
        for ip, mp in zip(img_files, msk_files):
            m = np.array(Image.open(mp), dtype=np.float32)
            if m.max() > 1: m = m / 255.0
            if m.sum() >= min_mask_sum:
                img = np.array(Image.open(ip), dtype=np.float32)
                if img.max() > 1: img = img / 255.0
                img = torch.from_numpy(img).float().unsqueeze(0)
                msk = torch.from_numpy(m).float().unsqueeze(0)
                self.cached.append((img, msk))
    def __len__(self):
        return len(self.cached)
    def __getitem__(self, idx):
        return self.cached[idx]

print('Pre-loading slices into RAM...')
cached_datasets = {}
for split, task_list in [('train', train_tasks), ('val', val_tasks), ('test', test_tasks)]:
    for t in tqdm(task_list, desc='Loading {}'.format(split)):
        cached_datasets[t] = SliceDataset(t, min_mask_sum=1.0)
print('Loaded datasets for', len(cached_datasets), 'tasks')
# Out:
# Train tasks: ['./train/task_2', './train/task_3', './train/task_5', './train/task_7']
# Val tasks  : ['./val/task_4', './val/task_6']
# Test tasks : ['./test/task_1', './test/task_8']
# Pre-loading slices into RAM...
# Loading train: 100%|██████████| 4/4 [00:04<00:00,  1.07s/it]
# Loading val: 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]
# Loading test: 100%|██████████| 2/2 [00:01<00:00,  1.71it/s]
# Loaded datasets for 8 tasks

# %% [markdown]
# ## 3. Simple U-Net model

# %%
class SimpleUNet(nn.Module):
    def __init__(self, in_channels=1, out_channels=1):
        super().__init__()
        self.c1a = nn.Conv2d(in_channels, 32, 3, padding=1)
        self.c1b = nn.Conv2d(32, 32, 3, padding=1)
        self.p1 = nn.MaxPool2d(2)
        self.c2a = nn.Conv2d(32, 64, 3, padding=1)
        self.c2b = nn.Conv2d(64, 64, 3, padding=1)
        self.p2 = nn.MaxPool2d(2)
        self.c3a = nn.Conv2d(64, 128, 3, padding=1)
        self.c3b = nn.Conv2d(128, 128, 3, padding=1)
        self.p3 = nn.MaxPool2d(2)
        self.c4a = nn.Conv2d(128, 256, 3, padding=1)
        self.c4b = nn.Conv2d(256, 256, 3, padding=1)
        self.up1 = nn.Upsample(scale_factor=2, mode='nearest')
        self.u1a = nn.Conv2d(256 + 128, 128, 3, padding=1)
        self.u1b = nn.Conv2d(128, 128, 3, padding=1)
        self.up2 = nn.Upsample(scale_factor=2, mode='nearest')
        self.u2a = nn.Conv2d(128 + 64, 64, 3, padding=1)
        self.u2b = nn.Conv2d(64, 64, 3, padding=1)
        self.up3 = nn.Upsample(scale_factor=2, mode='nearest')
        self.u3a = nn.Conv2d(64 + 32, 32, 3, padding=1)
        self.u3b = nn.Conv2d(32, 32, 3, padding=1)
        self.out = nn.Conv2d(32, out_channels, 1)
        self.act = nn.ReLU(inplace=True)
        self.final = nn.Sigmoid()
    def forward(self, x):
        x1 = self.act(self.c1b(self.act(self.c1a(x)))); p1 = self.p1(x1)
        x2 = self.act(self.c2b(self.act(self.c2a(p1)))); p2 = self.p2(x2)
        x3 = self.act(self.c3b(self.act(self.c3a(p2)))); p3 = self.p3(x3)
        b  = self.act(self.c4b(self.act(self.c4a(p3))))
        y = self.up1(b); y = torch.cat([y, x3], dim=1); y = self.act(self.u1b(self.act(self.u1a(y))))
        y = self.up2(y); y = torch.cat([y, x2], dim=1); y = self.act(self.u2b(self.act(self.u2a(y))))
        y = self.up3(y); y = torch.cat([y, x1], dim=1); y = self.act(self.u3b(self.act(self.u3a(y))))
        return self.final(self.out(y))

print('Model params:', sum(p.numel() for p in SimpleUNet().parameters()) )
# Out:
# Model params: 1946305

# %% [markdown]
# ## 4. Losses and metrics

# %%
def soft_dice_loss(pred, target, eps=1e-6):
    inter = (pred * target).sum(dim=(1,2,3))
    union = pred.sum(dim=(1,2,3)) + target.sum(dim=(1,2,3))
    dice = (2 * inter + eps) / (union + eps)
    return 1.0 - dice.mean()

def dice_score(pred, target, eps=1e-6):
    p = (pred > 0.5).float(); t = target.float()
    inter = (p * t).sum(dim=(1,2,3)); union = p.sum(dim=(1,2,3)) + t.sum(dim=(1,2,3))
    return ((2 * inter + eps) / (union + eps)).mean().item()

# %% [markdown]
# ## 5. Task sampling

# %%
def sample_task_episode(task_root, k_support=4, k_query=4):
    ds = cached_datasets[task_root]
    n = len(ds)
    if n == 0:
        raise ValueError('No usable slices in {}'.format(task_root))
    idxs = np.random.permutation(n)
    k_total = min(n, k_support + k_query)
    k_s = min(k_support, k_total // 2)
    k_q = min(k_query, k_total - k_s)
    xs, ys = zip(*[ds[i] for i in idxs[:k_s]])
    xq, yq = zip(*[ds[i] for i in idxs[k_s:k_s+k_q]]) if k_q > 0 else ([], [])
    xs = torch.stack(xs); ys = torch.stack(ys)
    xq = torch.stack(xq) if len(xq) else None
    yq = torch.stack(yq) if len(yq) else None
    return xs, ys, xq, yq

# %% [markdown]
# ## 6. Inner-loop adaptation (per task)

# %%
def inner_update(model, x_s, y_s, steps=3, lr_inner=1e-3, device=device):
    fast = copy.deepcopy(model).to(device)
    opt = torch.optim.SGD(fast.parameters(), lr=lr_inner)
    x_s, y_s = x_s.to(device), y_s.to(device)
    for _ in range(steps):
        opt.zero_grad()
        out = fast(x_s)
        if out.shape != y_s.shape: y_s = y_s.view_as(out)
        loss = F.binary_cross_entropy(out, y_s) + soft_dice_loss(out, y_s)
        loss.backward()
        opt.step()
    return fast

# %% [markdown]
# ## 7. Reptile meta-training with checkpoints

# %%
meta_config = {
    'meta_iters': 4000,
    'tasks_per_batch': 2,
    'k_support': 4,
    'k_query': 4,
    'lr_inner': 1e-3,
    'lr_meta': 0.1,
    'inner_steps': 5,
}

checkpoint_dir = 'checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)

def reptile_meta_train(model, train_tasks, device=device):
    model.to(device); model.train()
    meta_loss_history = []
    total_iters = meta_config['meta_iters']
    for it in range(total_iters):
        iter_start = datetime.now()
        meta_losses = []
        # zero pseudo-gradients
        for p in model.parameters():
            p.grad = torch.zeros_like(p.data)
        used_tasks = random.sample(train_tasks, k=min(meta_config['tasks_per_batch'], len(train_tasks)))
        print('=== Meta iteration {}/{} ==='.format(it+1, total_iters))
        print('Using tasks:', [os.path.basename(t) for t in used_tasks])
        for task_root in used_tasks:
            xs, ys, xq, yq = sample_task_episode(task_root, meta_config['k_support'], meta_config['k_query'])
            print('  Task {}: support {}, query {}'.format(os.path.basename(task_root), xs.shape, None if xq is None else xq.shape))
            fast_model = inner_update(model, xs, ys, steps=meta_config['inner_steps'], lr_inner=meta_config['lr_inner'], device=device)
            if xq is not None and yq is not None:
                xq, yq = xq.to(device), yq.to(device)
                with torch.no_grad():
                    out_q = fast_model(xq)
                    if out_q.shape != yq.shape: yq = yq.view_as(out_q)
                    bce = F.binary_cross_entropy(out_q, yq)
                    dls = soft_dice_loss(out_q, yq)
                    loss_q = bce + dls
                    meta_losses.append(loss_q.item())
                    print('    query BCE {:.4f}, DiceLoss {:.4f}, total {:.4f}'.format(bce.item(), dls.item(), loss_q.item()))
            for p, pf in zip(model.parameters(), fast_model.parameters()):
                p.grad.data.add_(pf.data - p.data)
        for p in model.parameters():
            p.grad.data.div_(len(used_tasks))
            p.data.add_(meta_config['lr_meta'] * p.grad.data)
        mean_loss = float('nan') if len(meta_losses) == 0 else float(np.mean(meta_losses))
        meta_loss_history.append(mean_loss)
        dt = (datetime.now() - iter_start).total_seconds()
        print('[Meta {}] mean query loss {:.4f}, took {:.1f}s'.format(it+1, mean_loss, dt))
        if (it + 1) % 25 == 0:
            ckpt = {'model_state': model.state_dict(), 'meta_loss_history': meta_loss_history, 'iter': it+1}
            path = os.path.join(checkpoint_dir, 'meta_iter_{}.pt'.format(it+1))
            torch.save(ckpt, path)
            print('  Saved checkpoint at iteration', it+1, '->', path)
    return meta_loss_history

meta_model = SimpleUNet(in_channels=1, out_channels=1)
meta_loss_history = reptile_meta_train(meta_model, train_tasks, device=device)
# Out:
# === Meta iteration 1/4000 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7344, DiceLoss 0.9384, total 1.6728
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7350, DiceLoss 0.9562, total 1.6912
# [Meta 1] mean query loss 1.6820, took 1.8s
# === Meta iteration 2/4000 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7342, DiceLoss 0.9411, total 1.6753
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7347, DiceLoss 0.9537, total 1.6884
# [Meta 2] mean query loss 1.6818, took 0.6s
# === Meta iteration 3/4000 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7337, DiceLoss 0.9348, total 1.6685
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7350, DiceLoss 0.9629, total 1.6980
# [Meta 3] mean query loss 1.6832, took 0.6s
# === Meta iteration 4/4000 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7339, DiceLoss 0.9405, total 1.6744
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7342, DiceLoss 0.9463, total 1.6805
# [Meta 4] mean query loss 1.6774, took 0.6s
# === Meta iteration 5/4000 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7340, DiceLoss 0.9466, total 1.6806
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7337, DiceLoss 0.9387, total 1.6724
# [Meta 5] mean query loss 1.6765, took 0.6s
# === Meta iteration 6/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7344, DiceLoss 0.9592, total 1.6936
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7323, DiceLoss 0.9211, total 1.6534
# [Meta 6] mean query loss 1.6735, took 0.6s
# === Meta iteration 7/4000 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7337, DiceLoss 0.9527, total 1.6864
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7324, DiceLoss 0.9166, total 1.6490
# [Meta 7] mean query loss 1.6677, took 0.6s
# === Meta iteration 8/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7331, DiceLoss 0.9346, total 1.6677
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7318, DiceLoss 0.9130, total 1.6448
# [Meta 8] mean query loss 1.6563, took 0.6s
# === Meta iteration 9/4000 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7343, DiceLoss 0.9700, total 1.7044
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7316, DiceLoss 0.9130, total 1.6446
# [Meta 9] mean query loss 1.6745, took 0.6s
# === Meta iteration 10/4000 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7330, DiceLoss 0.9414, total 1.6744
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7328, DiceLoss 0.9371, total 1.6700
# [Meta 10] mean query loss 1.6722, took 0.6s
# === Meta iteration 11/4000 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7337, DiceLoss 0.9592, total 1.6929
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7334, DiceLoss 0.9568, total 1.6902
# [Meta 11] mean query loss 1.6915, took 0.6s
# === Meta iteration 12/4000 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7339, DiceLoss 0.9720, total 1.7058
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7331, DiceLoss 0.9500, total 1.6831
# [Meta 12] mean query loss 1.6945, took 0.6s
# === Meta iteration 13/4000 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7322, DiceLoss 0.9382, total 1.6704
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7327, DiceLoss 0.9421, total 1.6749
# [Meta 13] mean query loss 1.6726, took 0.6s
# === Meta iteration 14/4000 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7309, DiceLoss 0.9120, total 1.6430
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7328, DiceLoss 0.9499, total 1.6828
# [Meta 14] mean query loss 1.6629, took 0.6s
# === Meta iteration 15/4000 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7322, DiceLoss 0.9417, total 1.6739
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7323, DiceLoss 0.9445, total 1.6768
# [Meta 15] mean query loss 1.6754, took 0.6s
# === Meta iteration 16/4000 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7319, DiceLoss 0.9368, total 1.6687
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7332, DiceLoss 0.9699, total 1.7031
# [Meta 16] mean query loss 1.6859, took 0.6s
# === Meta iteration 17/4000 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7326, DiceLoss 0.9561, total 1.6887
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7323, DiceLoss 0.9508, total 1.6831
# [Meta 17] mean query loss 1.6859, took 0.6s
# === Meta iteration 18/4000 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7321, DiceLoss 0.9479, total 1.6800
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7323, DiceLoss 0.9563, total 1.6886
# [Meta 18] mean query loss 1.6843, took 0.6s
# === Meta iteration 19/4000 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7322, DiceLoss 0.9562, total 1.6884
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7324, DiceLoss 0.9657, total 1.6981
# [Meta 19] mean query loss 1.6932, took 0.6s
# === Meta iteration 20/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7307, DiceLoss 0.9257, total 1.6564
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7305, DiceLoss 0.9214, total 1.6519
# [Meta 20] mean query loss 1.6541, took 0.6s
# === Meta iteration 21/4000 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7318, DiceLoss 0.9511, total 1.6828
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7321, DiceLoss 0.9661, total 1.6983
# [Meta 21] mean query loss 1.6905, took 0.6s
# === Meta iteration 22/4000 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7302, DiceLoss 0.9191, total 1.6493
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7305, DiceLoss 0.9282, total 1.6587
# [Meta 22] mean query loss 1.6540, took 0.6s
# === Meta iteration 23/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7313, DiceLoss 0.9493, total 1.6806
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7299, DiceLoss 0.9186, total 1.6485
# [Meta 23] mean query loss 1.6646, took 0.6s
# === Meta iteration 24/4000 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7304, DiceLoss 0.9349, total 1.6653
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7312, DiceLoss 0.9478, total 1.6790
# [Meta 24] mean query loss 1.6722, took 0.6s
# === Meta iteration 25/4000 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7317, DiceLoss 0.9634, total 1.6951
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7311, DiceLoss 0.9542, total 1.6853
# [Meta 25] mean query loss 1.6902, took 0.6s
#   Saved checkpoint at iteration 25 -> checkpoints/meta_iter_25.pt
# === Meta iteration 26/4000 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7288, DiceLoss 0.9093, total 1.6382
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7310, DiceLoss 0.9510, total 1.6819
# [Meta 26] mean query loss 1.6601, took 0.6s
# === Meta iteration 27/4000 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7306, DiceLoss 0.9446, total 1.6752
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7303, DiceLoss 0.9444, total 1.6747
# [Meta 27] mean query loss 1.6749, took 0.6s
# === Meta iteration 28/4000 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7292, DiceLoss 0.9197, total 1.6489
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7304, DiceLoss 0.9483, total 1.6787
# [Meta 28] mean query loss 1.6638, took 0.7s
# === Meta iteration 29/4000 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7301, DiceLoss 0.9432, total 1.6734
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7301, DiceLoss 0.9428, total 1.6729
# [Meta 29] mean query loss 1.6731, took 0.6s
# === Meta iteration 30/4000 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7304, DiceLoss 0.9574, total 1.6878
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7308, DiceLoss 0.9651, total 1.6959
# [Meta 30] mean query loss 1.6918, took 0.6s
# === Meta iteration 31/4000 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7299, DiceLoss 0.9512, total 1.6811
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7297, DiceLoss 0.9433, total 1.6730
# [Meta 31] mean query loss 1.6771, took 0.6s
# === Meta iteration 32/4000 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7293, DiceLoss 0.9356, total 1.6649
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7298, DiceLoss 0.9457, total 1.6755
# [Meta 32] mean query loss 1.6702, took 0.6s
# === Meta iteration 33/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7305, DiceLoss 0.9662, total 1.6966
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7297, DiceLoss 0.9492, total 1.6789
# [Meta 33] mean query loss 1.6878, took 0.6s
# === Meta iteration 34/4000 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7290, DiceLoss 0.9344, total 1.6634
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7280, DiceLoss 0.9114, total 1.6393
# [Meta 34] mean query loss 1.6514, took 0.6s
# === Meta iteration 35/4000 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7260, DiceLoss 0.8731, total 1.5990
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7300, DiceLoss 0.9612, total 1.6913
# [Meta 35] mean query loss 1.6451, took 0.6s
# === Meta iteration 36/4000 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7291, DiceLoss 0.9430, total 1.6721
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7301, DiceLoss 0.9725, total 1.7026
# [Meta 36] mean query loss 1.6874, took 0.6s
# === Meta iteration 37/4000 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7282, DiceLoss 0.9303, total 1.6585
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7294, DiceLoss 0.9564, total 1.6858
# [Meta 37] mean query loss 1.6722, took 0.6s
# === Meta iteration 38/4000 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7282, DiceLoss 0.9355, total 1.6637
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7283, DiceLoss 0.9365, total 1.6648
# [Meta 38] mean query loss 1.6643, took 0.6s
# === Meta iteration 39/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7285, DiceLoss 0.9411, total 1.6696
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7287, DiceLoss 0.9461, total 1.6748
# [Meta 39] mean query loss 1.6722, took 0.6s
# === Meta iteration 40/4000 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7281, DiceLoss 0.9408, total 1.6689
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7277, DiceLoss 0.9253, total 1.6530
# [Meta 40] mean query loss 1.6610, took 0.6s
# === Meta iteration 41/4000 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7276, DiceLoss 0.9256, total 1.6532
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7294, DiceLoss 0.9696, total 1.6989
# [Meta 41] mean query loss 1.6761, took 0.6s
# === Meta iteration 42/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7288, DiceLoss 0.9609, total 1.6897
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7279, DiceLoss 0.9405, total 1.6684
# [Meta 42] mean query loss 1.6791, took 0.6s
# === Meta iteration 43/4000 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7269, DiceLoss 0.9185, total 1.6454
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7279, DiceLoss 0.9399, total 1.6677
# [Meta 43] mean query loss 1.6566, took 0.6s
# === Meta iteration 44/4000 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7267, DiceLoss 0.9176, total 1.6443
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7258, DiceLoss 0.9016, total 1.6274
# [Meta 44] mean query loss 1.6359, took 0.6s
# === Meta iteration 45/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7266, DiceLoss 0.9173, total 1.6439
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7258, DiceLoss 0.8996, total 1.6254
# [Meta 45] mean query loss 1.6346, took 0.6s
# === Meta iteration 46/4000 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7283, DiceLoss 0.9666, total 1.6949
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7280, DiceLoss 0.9546, total 1.6826
# [Meta 46] mean query loss 1.6887, took 0.6s
# === Meta iteration 47/4000 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7276, DiceLoss 0.9536, total 1.6812
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7274, DiceLoss 0.9400, total 1.6674
# [Meta 47] mean query loss 1.6743, took 0.6s
# === Meta iteration 48/4000 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7281, DiceLoss 0.9688, total 1.6969
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7265, DiceLoss 0.9242, total 1.6507
# [Meta 48] mean query loss 1.6738, took 0.6s
# === Meta iteration 49/4000 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7278, DiceLoss 0.9687, total 1.6965
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7257, DiceLoss 0.9084, total 1.6341
# [Meta 49] mean query loss 1.6653, took 0.6s
# === Meta iteration 50/4000 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7259, DiceLoss 0.9203, total 1.6462
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7265, DiceLoss 0.9360, total 1.6625
# [Meta 50] mean query loss 1.6543, took 0.6s
#   Saved checkpoint at iteration 50 -> checkpoints/meta_iter_50.pt
# === Meta iteration 51/4000 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7270, DiceLoss 0.9490, total 1.6761
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7248, DiceLoss 0.8997, total 1.6244
# [Meta 51] mean query loss 1.6503, took 0.6s
# === Meta iteration 52/4000 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7251, DiceLoss 0.9082, total 1.6333
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7252, DiceLoss 0.9075, total 1.6327
# [Meta 52] mean query loss 1.6330, took 0.6s
# === Meta iteration 53/4000 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7274, DiceLoss 0.9694, total 1.6968
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7269, DiceLoss 0.9565, total 1.6834
# [Meta 53] mean query loss 1.6901, took 0.6s
# === Meta iteration 54/4000 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7255, DiceLoss 0.9263, total 1.6518
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7254, DiceLoss 0.9193, total 1.6447
# [Meta 54] mean query loss 1.6482, took 0.6s
# === Meta iteration 55/4000 ===
# Using tasks: ['task_2', 'task_3']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7250, DiceLoss 0.9145, total 1.6395
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7255, DiceLoss 0.9329, total 1.6584
# [Meta 55] mean query loss 1.6490, took 0.6s
# === Meta iteration 56/4000 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7264, DiceLoss 0.9536, total 1.6800
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7257, DiceLoss 0.9434, total 1.6691
# [Meta 56] mean query loss 1.6746, took 0.6s
# === Meta iteration 57/4000 ===
# Using tasks: ['task_3', 'task_2']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7259, DiceLoss 0.9509, total 1.6768
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7259, DiceLoss 0.9487, total 1.6747
# [Meta 57] mean query loss 1.6757, took 0.6s
# === Meta iteration 58/4000 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7246, DiceLoss 0.9205, total 1.6451
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7263, DiceLoss 0.9602, total 1.6865
# [Meta 58] mean query loss 1.6658, took 0.6s
# === Meta iteration 59/4000 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7255, DiceLoss 0.9480, total 1.6735
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7272, DiceLoss 0.9919, total 1.7191
# [Meta 59] mean query loss 1.6963, took 0.6s
# === Meta iteration 60/4000 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7246, DiceLoss 0.9301, total 1.6546
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7255, DiceLoss 0.9498, total 1.6754
# [Meta 60] mean query loss 1.6650, took 0.6s
# === Meta iteration 61/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7255, DiceLoss 0.9569, total 1.6824
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7250, DiceLoss 0.9415, total 1.6665
# [Meta 61] mean query loss 1.6744, took 0.6s
# === Meta iteration 62/4000 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7249, DiceLoss 0.9408, total 1.6658
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7251, DiceLoss 0.9472, total 1.6723
# [Meta 62] mean query loss 1.6690, took 0.6s
# === Meta iteration 63/4000 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7233, DiceLoss 0.9021, total 1.6254
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7251, DiceLoss 0.9501, total 1.6752
# [Meta 63] mean query loss 1.6503, took 0.6s
# === Meta iteration 64/4000 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7231, DiceLoss 0.9020, total 1.6251
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7252, DiceLoss 0.9589, total 1.6840
# [Meta 64] mean query loss 1.6546, took 0.6s
# === Meta iteration 65/4000 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7245, DiceLoss 0.9439, total 1.6685
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7242, DiceLoss 0.9331, total 1.6572
# [Meta 65] mean query loss 1.6629, took 0.6s
# === Meta iteration 66/4000 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7249, DiceLoss 0.9591, total 1.6840
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7253, DiceLoss 0.9731, total 1.6984
# [Meta 66] mean query loss 1.6912, took 0.6s
# === Meta iteration 67/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7248, DiceLoss 0.9587, total 1.6835
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7245, DiceLoss 0.9499, total 1.6744
# [Meta 67] mean query loss 1.6789, took 0.6s
# === Meta iteration 68/4000 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7238, DiceLoss 0.9392, total 1.6631
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7245, DiceLoss 0.9568, total 1.6813
# [Meta 68] mean query loss 1.6722, took 0.6s
# === Meta iteration 69/4000 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7236, DiceLoss 0.9365, total 1.6601
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7230, DiceLoss 0.9184, total 1.6413
# [Meta 69] mean query loss 1.6507, took 0.6s
# === Meta iteration 70/4000 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7243, DiceLoss 0.9575, total 1.6818
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7239, DiceLoss 0.9505, total 1.6744
# [Meta 70] mean query loss 1.6781, took 0.6s
# === Meta iteration 71/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7238, DiceLoss 0.9494, total 1.6732
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7242, DiceLoss 0.9563, total 1.6805
# [Meta 71] mean query loss 1.6769, took 0.6s
# === Meta iteration 72/4000 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7234, DiceLoss 0.9438, total 1.6672
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7239, DiceLoss 0.9583, total 1.6821
# [Meta 72] mean query loss 1.6747, took 0.6s
# === Meta iteration 73/4000 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7231, DiceLoss 0.9409, total 1.6641
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7237, DiceLoss 0.9533, total 1.6770
# [Meta 73] mean query loss 1.6705, took 0.6s
# === Meta iteration 74/4000 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7247, DiceLoss 0.9887, total 1.7133
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7233, DiceLoss 0.9499, total 1.6733
# [Meta 74] mean query loss 1.6933, took 0.6s
# === Meta iteration 75/4000 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7231, DiceLoss 0.9473, total 1.6704
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7230, DiceLoss 0.9443, total 1.6673
# [Meta 75] mean query loss 1.6689, took 0.6s
#   Saved checkpoint at iteration 75 -> checkpoints/meta_iter_75.pt
# === Meta iteration 76/4000 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7225, DiceLoss 0.9351, total 1.6576
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7232, DiceLoss 0.9533, total 1.6765
# [Meta 76] mean query loss 1.6670, took 0.6s
# === Meta iteration 77/4000 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7217, DiceLoss 0.9194, total 1.6411
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7231, DiceLoss 0.9553, total 1.6785
# [Meta 77] mean query loss 1.6598, took 0.6s
# === Meta iteration 78/4000 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7223, DiceLoss 0.9377, total 1.6600
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7226, DiceLoss 0.9440, total 1.6666
# [Meta 78] mean query loss 1.6633, took 0.6s
# === Meta iteration 79/4000 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7222, DiceLoss 0.9394, total 1.6616
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7224, DiceLoss 0.9530, total 1.6754
# [Meta 79] mean query loss 1.6685, took 0.6s
# === Meta iteration 80/4000 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7212, DiceLoss 0.9161, total 1.6373
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7220, DiceLoss 0.9427, total 1.6648
# [Meta 80] mean query loss 1.6511, took 0.6s
# === Meta iteration 81/4000 ===
# Using tasks: ['task_5', 'task_7']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7221, DiceLoss 0.9474, total 1.6695
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7219, DiceLoss 0.9422, total 1.6640
# [Meta 81] mean query loss 1.6668, took 0.6s
# === Meta iteration 82/4000 ===
# Using tasks: ['task_3', 'task_5']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7221, DiceLoss 0.9492, total 1.6713
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7224, DiceLoss 0.9613, total 1.6837
# [Meta 82] mean query loss 1.6775, took 0.6s
# === Meta iteration 83/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7221, DiceLoss 0.9575, total 1.6797
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7208, DiceLoss 0.9193, total 1.6401
# [Meta 83] mean query loss 1.6599, took 0.6s
# === Meta iteration 84/4000 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7222, DiceLoss 0.9611, total 1.6833
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7218, DiceLoss 0.9520, total 1.6739
# [Meta 84] mean query loss 1.6786, took 0.6s
# === Meta iteration 85/4000 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7215, DiceLoss 0.9466, total 1.6681
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7215, DiceLoss 0.9484, total 1.6699
# [Meta 85] mean query loss 1.6690, took 0.6s
# === Meta iteration 86/4000 ===
# Using tasks: ['task_7', 'task_5']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7215, DiceLoss 0.9500, total 1.6716
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7210, DiceLoss 0.9403, total 1.6613
# [Meta 86] mean query loss 1.6664, took 0.6s
# === Meta iteration 87/4000 ===
# Using tasks: ['task_2', 'task_5']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7209, DiceLoss 0.9378, total 1.6587
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7209, DiceLoss 0.9393, total 1.6601
# [Meta 87] mean query loss 1.6594, took 0.6s
# === Meta iteration 88/4000 ===
# Using tasks: ['task_3', 'task_7']
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7184, DiceLoss 0.8737, total 1.5922
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7213, DiceLoss 0.9519, total 1.6732
# [Meta 88] mean query loss 1.6327, took 0.6s
# === Meta iteration 89/4000 ===
# Using tasks: ['task_7', 'task_3']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7209, DiceLoss 0.9482, total 1.6691
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7206, DiceLoss 0.9341, total 1.6547
# [Meta 89] mean query loss 1.6619, took 0.6s
# === Meta iteration 90/4000 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7202, DiceLoss 0.9288, total 1.6490
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7199, DiceLoss 0.9259, total 1.6459
# [Meta 90] mean query loss 1.6475, took 0.6s
# === Meta iteration 91/4000 ===
# Using tasks: ['task_5', 'task_2']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7209, DiceLoss 0.9570, total 1.6779
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7204, DiceLoss 0.9408, total 1.6613
# [Meta 91] mean query loss 1.6696, took 0.6s
# === Meta iteration 92/4000 ===
# Using tasks: ['task_2', 'task_7']
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7211, DiceLoss 0.9713, total 1.6924
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7196, DiceLoss 0.9219, total 1.6415
# [Meta 92] mean query loss 1.6670, took 0.6s
# === Meta iteration 93/4000 ===
# Using tasks: ['task_7', 'task_2']
#   Task task_7: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7202, DiceLoss 0.9441, total 1.6642
#   Task task_2: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7195, DiceLoss 0.9259, total 1.6454
# [Meta 93] mean query loss 1.6548, took 0.6s
# === Meta iteration 94/4000 ===
# Using tasks: ['task_5', 'task_3']
#   Task task_5: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
#     query BCE 0.7210, DiceLoss 0.9749, total 1.6959
#   Task task_3: support torch.Size([4, 1, 192, 192]), query torch.Size([4, 1, 192, 192])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 58
#      55     return meta_loss_history
#      57 meta_model = SimpleUNet(in_channels=1, out_channels=1)
# ---> 58 meta_loss_history = reptile_meta_train(meta_model, train_tasks, device=device)
#
# Cell In[9], line 30, in reptile_meta_train(model, train_tasks, device)
#      28 xs, ys, xq, yq = sample_task_episode(task_root, meta_config['k_support'], meta_config['k_query'])
#      29 print('  Task {}: support {}, query {}'.format(os.path.basename(task_root), xs.shape, None if xq is None else xq.shape))
# ---> 30 fast_model = inner_update(model, xs, ys, steps=meta_config['inner_steps'], lr_inner=meta_config['lr_inner'], device=device)
#      31 if xq is not None and yq is not None:
#      32     xq, yq = xq.to(device), yq.to(device)
#
# Cell In[8], line 11, in inner_update(model, x_s, y_s, steps, lr_inner, device)
#       9     loss = F.binary_cross_entropy(out, y_s) + soft_dice_loss(out, y_s)
#      10     loss.backward()
# ---> 11     opt.step()
#      12 return fast
#
# File ~/env/EMS741/lib/python3.10/site-packages/torch/optim/optimizer.py:526, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     521             raise RuntimeError(
#     522                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     523             )
#     525 # pyrefly: ignore [invalid-param-spec]
# --> 526 out = func(*args, **kwargs)
#     527 self._optimizer_step_code()
#     529 # call optimizer step post hooks
#
# File ~/env/EMS741/lib/python3.10/site-packages/torch/optim/optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File ~/env/EMS741/lib/python3.10/site-packages/torch/optim/sgd.py:127, in SGD.step(self, closure)
#     121 momentum_buffer_list: list[Tensor | None] = []
#     123 has_sparse_grad = self._init_group(
#     124     group, params, grads, momentum_buffer_list
#     125 )
# --> 127 sgd(
#     128     params,
#     129     grads,
#     130     momentum_buffer_list,
#     131     weight_decay=group["weight_decay"],
#     132     momentum=group["momentum"],
#     133     lr=group["lr"],
#     134     dampening=group["dampening"],
#     135     nesterov=group["nesterov"],
#     136     maximize=group["maximize"],
#     137     has_sparse_grad=has_sparse_grad,
#     138     foreach=group["foreach"],
#     139     fused=group["fused"],
#     140     grad_scale=getattr(self, "grad_scale", None),
#     141     found_inf=getattr(self, "found_inf", None),
#     142 )
#     144 if group["momentum"] != 0:
#     145     # update momentum_buffers in state
#     146     for p, momentum_buffer in zip(
#     147         params, momentum_buffer_list, strict=True
#     148     ):
#
# File ~/env/EMS741/lib/python3.10/site-packages/torch/optim/sgd.py:283, in sgd(params, d_p_list, momentum_buffer_list, has_sparse_grad, foreach, fused, grad_scale, found_inf, weight_decay, momentum, lr, dampening, nesterov, maximize)
#     279 if foreach is None and fused is None:
#     280     # why must we be explicit about an if statement for torch.jit.is_scripting here?
#     281     # because JIT can't handle Optionals nor fancy conditionals when scripting
#     282     if not torch.jit.is_scripting():
# --> 283         fused, foreach = _default_to_fused_or_foreach(
#     284             params, differentiable=False, use_fused=False
#     285         )
#     286     else:
#     287         foreach = False
#
# File ~/env/EMS741/lib/python3.10/site-packages/torch/optim/optimizer.py:181, in _default_to_fused_or_foreach(params, differentiable, use_fused)
#     171 foreach_supported_devices = _get_foreach_kernels_supported_devices()
#     172 fused = use_fused and all(
#     173     p is None
#     174     or (
#    (...)
#     179     for p in params
#     180 )
# --> 181 foreach = not fused and all(
#     182     p is None
#     183     or (
#     184         type(p) in _foreach_supported_types
#     185         and p.device.type in foreach_supported_devices
#     186     )
#     187     for p in params
#     188 )
#     189 return fused, foreach
#
# File ~/env/EMS741/lib/python3.10/site-packages/torch/optim/optimizer.py:181, in <genexpr>(.0)
#     171 foreach_supported_devices = _get_foreach_kernels_supported_devices()
#     172 fused = use_fused and all(
#     173     p is None
#     174     or (
#    (...)
#     179     for p in params
#     180 )
# --> 181 foreach = not fused and all(
#     182     p is None
#     183     or (
#     184         type(p) in _foreach_supported_types
#     185         and p.device.type in foreach_supported_devices
#     186     )
#     187     for p in params
#     188 )
#     189 return fused, foreach
#
# KeyboardInterrupt:

# %% [markdown]
# ## 8. Load a chosen checkpoint (optional)

# %%
RUN_OPTIONAL_PART_8 = False
if RUN_OPTIONAL_PART_8:
    # Set this to the checkpoint you want to resume/evaluate from
    checkpoint_path = os.path.join('checkpoints', 'meta_iter_4000.pt')  # change if needed

    if os.path.exists(checkpoint_path):
        ckpt = torch.load(checkpoint_path, map_location=device)
        meta_model = SimpleUNet(in_channels=1, out_channels=1).to(device)
        meta_model.load_state_dict(ckpt['model_state'])
        print('Loaded checkpoint from:', checkpoint_path)
        print('Stored iteration index:', ckpt.get('iter'))
        print('Last 10 meta-loss values:', ckpt.get('meta_loss_history', [])[-10:])
    else:
        print('Checkpoint not found at', checkpoint_path, '- using freshly trained meta_model instead.')
else:
    print('Skipping optional part 8 (set RUN_OPTIONAL_PART_8=True to enable).')
# Out:
# Skipping optional part 8 (set RUN_OPTIONAL_PART_8=True to enable).

# %% [markdown]
# ## 9. Few-shot evaluation with qualitative images

# %%
# Global store for evaluation runs
if 'ALL_EVAL_RESULTS' not in globals():
    ALL_EVAL_RESULTS = []

def eval_task_with_images_and_log(model, task_root, shots=4, steps=10, lr_inner=1e-3, device=device, n_vis=3, batch_size=8):
    ds = cached_datasets[task_root]
    n = len(ds)
    if n <= shots:
        raise ValueError('Not enough slices in {}'.format(task_root))
    
    idxs = np.random.permutation(n)
    xs, ys = zip(*[ds[i] for i in idxs[:shots]])
    xs, ys = torch.stack(xs).to(device), torch.stack(ys).to(device)
    
    query_idxs = idxs[shots:]
    
    adapted = copy.deepcopy(model).to(device)
    opt = torch.optim.SGD(adapted.parameters(), lr=lr_inner)
    
    for _ in range(steps):
        opt.zero_grad()
        out_s = adapted(xs)
        if out_s.shape != ys.shape: ys = ys.view_as(out_s)
        loss = F.binary_cross_entropy(out_s, ys) + soft_dice_loss(out_s, ys)
        loss.backward()
        opt.step()
    
    # Batched query eval to prevent OOM
    all_batch_imgs = []  
    all_batch_gts  = []
    all_batch_preds= []
    
    with torch.no_grad():
        for i in range(0, len(query_idxs), batch_size):
            end = min(i + batch_size, len(query_idxs))
            xq_b, yq_b = zip(*[ds[j] for j in query_idxs[i:end]])
            xq_b, yq_b = torch.stack(xq_b).to(device), torch.stack(yq_b).to(device)
            
            out_q_b = adapted(xq_b)
            
            # Store everything on CPU to save VRAM
            all_batch_imgs.append(xq_b.cpu())
            all_batch_gts.append(yq_b.cpu())
            all_batch_preds.append(out_q_b.cpu())

    # Reconstruct full volume on CPU to fix the Dice math
    full_xq = torch.cat(all_batch_imgs, dim=0)
    full_yq = torch.cat(all_batch_gts, dim=0)
    full_out_q = torch.cat(all_batch_preds, dim=0)
    
    mean_dice = dice_score(full_out_q, full_yq)
    print('Task {} | {}-shot Dice: {:.4f}'.format(os.path.basename(task_root), shots, mean_dice))
    
    # Save visuals
    results_root = 'results'
    img_dir = os.path.join(results_root, 'images')
    os.makedirs(img_dir, exist_ok=True)
    saved_paths = []
    
    k = min(n_vis, full_xq.shape[0])
    for i in range(k):
        img = full_xq[i,0].numpy()
        gt  = full_yq[i,0].numpy()
        pr  = (full_out_q[i,0].numpy() > 0.5).astype(float)
        
        base = 'task_{}_shots_{}_idx_{}'.format(os.path.basename(task_root), shots, i)
        img_path  = os.path.join(img_dir, base + '_img.png')
        gt_path   = os.path.join(img_dir, base + '_gt.png')
        pred_path = os.path.join(img_dir, base + '_pred.png')
        
        plt.imsave(img_path, img, cmap='gray')
        plt.imsave(gt_path,  gt,  cmap='gray')
        plt.imsave(pred_path, pr, cmap='gray')
        saved_paths.extend([img_path, gt_path, pred_path])
        
        fig, axs = plt.subplots(1,3,figsize=(9,3))
        axs[0].imshow(img, cmap='gray'); axs[0].set_title('Image'); axs[0].axis('off')
        axs[1].imshow(gt, cmap='gray'); axs[1].set_title('GT mask'); axs[1].axis('off')
        axs[2].imshow(pr, cmap='gray'); axs[2].set_title('Pred mask'); axs[2].axis('off')
        plt.show()

    ALL_EVAL_RESULTS.append({
        'task': task_root,
        'shots': int(shots),
        'dice': float(mean_dice),
        'image_paths': saved_paths,
    })
    
    return mean_dice

# ==== RUN FULL EVALUATION ====
print('Running evaluation on all validation tasks...')

# Define evaluation parameters here as variables
eval_steps_used = 50
eval_lr_used = 1e-3
eval_batch_size_used = 8
n_vis_used = 2

for t in val_tasks:
    for s in [1, 3, 5]:
        eval_task_with_images_and_log(
            meta_model, 
            t, 
            shots=s, 
            steps=eval_steps_used, 
            lr_inner=eval_lr_used, 
            device=device, 
            n_vis=n_vis_used,
            batch_size=eval_batch_size_used
        )
# Out:
# Running evaluation on all validation tasks...
# Task task_4 | 1-shot Dice: 0.0380
# Task task_4 | 3-shot Dice: 0.0381
# Task task_4 | 5-shot Dice: 0.0381
# Task task_6 | 1-shot Dice: 0.0703
# Task task_6 | 3-shot Dice: 0.0703
# Task task_6 | 5-shot Dice: 0.0702

# %% [markdown]
# ## 10. Save results (images + metrics) as a ZIP

# %%
# === Final cell: package everything into a ZIP ===

results_root = 'results'
os.makedirs(results_root, exist_ok=True)

# Compute highest dice
if 'ALL_EVAL_RESULTS' in globals() and len(ALL_EVAL_RESULTS) > 0:
    best_dice = max(r['dice'] for r in ALL_EVAL_RESULTS)
else:
    best_dice = 0.0

script_name = os.path.splitext(os.path.basename(__file__))[0] if '__file__' in globals() else 'ems741_reptile_gpu_export'
now_str = datetime.now().strftime('%Y%m%d_%H%M%S')

# Create a descriptive zip file name using your training and eval parameters
zip_name = 'EMS741_iters_{}_steps_{}_dice_{:.4f}_{}.zip'.format(meta_config['meta_iters'], eval_steps_used, best_dice, now_str)
zip_path = os.path.join(results_root, zip_name)

# Also save a JSON summary with full configuration
summary_path = os.path.join(results_root, 'summary.json')

run_config = {
    'meta_config': meta_config,  # logs all training hyperparameters
    'eval_config': {
        'eval_steps': eval_steps_used,
        'eval_lr_inner': eval_lr_used,
        'eval_batch_size': eval_batch_size_used,
        'n_vis_per_task': n_vis_used
    },
    'best_dice': best_dice, 
    'results': ALL_EVAL_RESULTS
}

with open(summary_path, 'w') as f:
    json.dump(run_config, f, indent=2)

# Build ZIP: include images + summary
with zipfile.ZipFile(zip_path, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
    # Add summary.json to the zip
    if os.path.exists(summary_path):
        zf.write(summary_path, arcname=os.path.basename(summary_path))
    
    # Add all images from the results/images directory
    img_dir = os.path.join(results_root, 'images')
    if os.path.isdir(img_dir):
        for root, _, files in os.walk(img_dir):
            for fname in files:
                full = os.path.join(root, fname)
                rel  = os.path.relpath(full, results_root)
                zf.write(full, arcname=rel)

print('Saved results ZIP to:', zip_path)
# Out:
# Saved results ZIP to: results/EMS741_iters_4000_steps_50_dice_0.0703_20260326_223622.zip
